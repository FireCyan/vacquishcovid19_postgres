# %%
import aws_util
import pandas as pd

# %%
db_name = 'covid19_db'
conn, cur = aws_util.conn_db(db_name)

# %%
conn.close()

# %% [markdown]
# ## Create database and tables

# %%
import create_table

# %%
create_table.create_tables(conn, cur)

# %%
# Get all the available tables
cur.execute('''
SELECT table_name
  FROM information_schema.tables
 WHERE table_schema='public'
   AND table_type='BASE TABLE';''')

cur.fetchall()

# %%
create_table.main()
# Out:
# --- Creating database -----
# connecting to AWS RDS Postgres default_db
# Dropping database if exists...
# Creating database covid19_db...
# Connecting to AWS RDS database covid19_db...
# --- Finish creating database ---
# --- Dropping tables in db ---
# ---Finish dropping tables ---
# --- Creating tables in db ---
# --- Finish creating tables ---

# %% [markdown]
# ## Processing

# %%
import etl

# %%
test_sql = """
    SELECT *
    FROM daily_case
"""

df_test = pd.read_sql(test_sql, conn)

# %%
csv_record_sql = """
    SELECT *
    FROM csv_record
    where data_type <> 'vac'
"""

df_csv_record = pd.read_sql(csv_record_sql, conn)

# %%
df_csv_record
# Out:
# Empty DataFrame
# Columns: [file_name, data_type, last_update]
# Index: []

# %% [markdown]
# ##### pre-process old format files

# %%
# If pre-process only a few
# list_old = ['01-22-2020.csv', '03-21-2020.csv']
# etl.preprocess_case_data(list_old=list_old)

# %%
# If pre-process all
# etl.preprocess_case_data()

# %% [markdown]
# ##### Main processing

# %%
query, tuples = etl.process_case_data(process_all=True)
# Out:
# ----- Start processing daily case data -----
# Determining which daily case csv files to process based on csv_record table...
# Loading and processing daily case data...
# 01-01-2021.csv
# 01-02-2021.csv
# 01-03-2021.csv
# 01-04-2021.csv
# 01-05-2021.csv
# 01-06-2021.csv
# 01-07-2021.csv
# 01-08-2021.csv
# 01-09-2021.csv
# 01-10-2021.csv
# 01-11-2021.csv
# 01-12-2021.csv
# 01-13-2021.csv
# 01-14-2021.csv
# 01-15-2021.csv
# 01-16-2021.csv
# 01-17-2021.csv
# 01-18-2021.csv
# 01-19-2021.csv
# 01-20-2021.csv
# 01-21-2021.csv
# 01-22-2021.csv
# 01-23-2021.csv
# 01-24-2021.csv
# 01-25-2021.csv
# 01-26-2021.csv
# 01-27-2021.csv
# 01-28-2021.csv
# 01-29-2021.csv
# 01-30-2021.csv
# 01-31-2021.csv
# 02-01-2021.csv
# 02-02-2021.csv
# 02-03-2021.csv
# 02-04-2021.csv
# 02-05-2021.csv
# 02-06-2021.csv
# 02-07-2021.csv
# 02-08-2021.csv
# 02-09-2021.csv
# 02-10-2021.csv
# 02-11-2021.csv
# 02-12-2021.csv
# 02-13-2021.csv
# 02-14-2021.csv
# 02-15-2021.csv
# 02-16-2021.csv
# 02-17-2021.csv
# 02-18-2021.csv
# 02-19-2021.csv
# 02-20-2021.csv
# 02-21-2021.csv
# 02-22-2021.csv
# 02-23-2021.csv
# 02-24-2021.csv
# 02-25-2021.csv
# 02-26-2021.csv
# 02-27-2021.csv
# 02-28-2021.csv
# 03-01-2021.csv
# 03-02-2021.csv
# 03-03-2021.csv
# 03-04-2021.csv
# 03-05-2021.csv
# 03-06-2021.csv
# 03-07-2021.csv
# 03-08-2021.csv
# 03-09-2021.csv
FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   time_data = (t.dt.strftime('%Y-%m-%d %H:%M:%S'), t.dt.hour.values, t.dt.day.values, t.dt.weekofyear.values, t.dt.month.values, t.dt.year.values, t.dt.weekday.values)
# Loading and processing old daily case data...
# 01-22-2020.csv
# 01-23-2020.csv
# 01-24-2020.csv
# 01-25-2020.csv
# 01-26-2020.csv
# 01-27-2020.csv
# 01-28-2020.csv
# 01-29-2020.csv
# 01-30-2020.csv
# 01-31-2020.csv
# 02-01-2020.csv
# 02-02-2020.csv
# 02-03-2020.csv
# 02-04-2020.csv
# 02-05-2020.csv
# 02-06-2020.csv
# 02-07-2020.csv
# 02-08-2020.csv
# 02-09-2020.csv
# 02-10-2020.csv
# 02-11-2020.csv
# 02-12-2020.csv
# 02-13-2020.csv
# 02-14-2020.csv
# 02-15-2020.csv
# 02-16-2020.csv
# 02-17-2020.csv
# 02-18-2020.csv
# 02-19-2020.csv
# 02-20-2020.csv
# 02-21-2020.csv
# 02-22-2020.csv
# 02-23-2020.csv
# 02-24-2020.csv
# 02-25-2020.csv
# 02-26-2020.csv
# 02-27-2020.csv
# 02-28-2020.csv
# 02-29-2020.csv
# 03-01-2020.csv
# 03-02-2020.csv
# 03-03-2020.csv
# 03-04-2020.csv
# 03-05-2020.csv
# 03-06-2020.csv
# 03-07-2020.csv
# 03-08-2020.csv
# 03-09-2020.csv
# 03-10-2020.csv
# 03-11-2020.csv
# 03-12-2020.csv
# 03-13-2020.csv
# 03-14-2020.csv
# 03-15-2020.csv
# 03-16-2020.csv
# 03-17-2020.csv
# 03-18-2020.csv
# 03-19-2020.csv
# 03-20-2020.csv
# 03-21-2020.csv
# C:\John_folder\github_projects\vacquishcovid19_postgres\etl.py:255: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   time_data = (t.dt.strftime('%Y-%m-%d %H:%M:%S'), t.dt.hour.values, t.dt.day.values, t.dt.weekofyear.values, t.dt.month.values, t.dt.year.values, t.dt.weekday.values)
# Bulk inserting processed daily case data into daily case table...
#   FIPS Admin2 Province_State Country_Region date_string          Last_Update  \
# 0                               Afghanistan  2021-01-01  2021-01-02 05:22:33
# 1                                   Albania  2021-01-01  2021-01-02 05:22:33
# 2                                   Algeria  2021-01-01  2021-01-02 05:22:33
# 3                                   Andorra  2021-01-01  2021-01-02 05:22:33
# 4                                    Angola  2021-01-01  2021-01-02 05:22:33
#
#   Confirmed Deaths Recovered Active
# 0     51526   2191     41727      0
# 1     58316   1181     33634  23501
# 2     99897   2762     67395  29740
# 3      8117     84      7463    570
# 4     17568    405     11146   6017
# Start bulk inserting...
# Successfully inserted chunk0 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk1 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk2 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk3 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk4 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk5 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk6 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk7 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk8 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk9 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk10 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk11 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk12 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk13 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk14 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk15 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk16 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk17 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk18 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk19 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk20 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk21 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk22 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk23 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk24 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk25 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk26 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk27 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk28 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk29 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk30 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk31 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk32 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk33 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk34 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk35 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk36 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk37 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk38 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk39 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk40 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk41 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk42 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk43 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk44 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk45 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk46 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk47 of 1000 rows
# Start bulk inserting...
# Successfully inserted chunk48 of 1000 rows
# Start bulk inserting...
# Successfully inserted chun
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-562317a87e65> in <module>
# ----> 1 etl.process_case_data(file_date='2021-07-19')
#
# C:\John_folder\github_projects\vacquishcovid19_postgres\etl.py in process_case_data(file_date, process_all, reload_country)
#     131             file_to_dl.append(datetime.strftime(datetime.strptime(file_date[0], '%Y-%m-%d'), '%m-%d-%Y'))
#     132         else:
# --> 133             start_date = datetime.strptime(file_date[0], '%Y-%m-%d')
#     134             end_date = datetime.strptime(file_date[1], '%Y-%m-%d')
#     135             delta = end_date - start_date
#
# ~\anaconda3\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# ~\anaconda3\lib\_strptime.py in _strptime(data_string, format)
#     347     found = format_regex.match(data_string)
#     348     if not found:
# --> 349         raise ValueError("time data %r does not match format %r" %
#     350                          (data_string, format))
#     351     if len(data_string) != found.end():
#
# ValueError: time data '2' does not match format '%Y-%m-%d'

# %%
df_case_test = pd.read_sql("""
SELECT * FROM daily_case WHERE (country_region = 'France') and (province_state is Null) and (date_string > '2021-04-01')
""", conn)
df_case_test
# Out:
#     fips admin2 province_state country_region date_string  \
# 0   None   None           None         France  2021-04-04
# 1   None   None           None         France  2021-04-02
# 2   None   None           None         France  2021-04-03
# 3   None   None           None         France  2021-04-05
# 4   None   None           None         France  2021-04-06
# 5   None   None           None         France  2021-04-07
# 6   None   None           None         France  2021-04-08
# 7   None   None           None         France  2021-04-11
# 8   None   None           None         France  2021-04-12
# 9   None   None           None         France  2021-04-13
# 10  None   None           None         France  2021-04-14
# 11  None   None           None         France  2021-04-15
# 12  None   None           None         France  2021-04-09
# 13  None   None           None         France  2021-04-10
# 14  None   None           None         France  2021-04-16
# 15  None   None           None         France  2021-04-17
# 16  None   None           None         France  2021-04-18
# 17  None   None           None         France  2021-04-19
#
#             last_update  confirmed  deaths  recovered   active
# 0   2021-04-04 04:20:49    4707488   95677     267607  4344123
# 1   2021-04-02 04:20:36    4661841   95356     266039  4300446
# 2   2021-04-03 04:20:44    4708648   95683     267607  4345358
# 3   2021-04-05 04:20:35    4788117   96046     269497  4422574
# 4   2021-04-06 04:20:32    4799078   96243     269937  4432898
# 5   2021-04-07 04:20:53    4807123   96672     269989  4440462
# 6   2021-04-08 04:21:13    4807123   96672     269989  4439553
# 7   2021-04-11 04:20:56    4903965   97422     274401  4530637
# 8   2021-04-12 04:21:00    5021865   98118     278477  4645270
# 9   2021-04-13 04:20:37    5030401   98503     279624  4652274
# 10  2021-04-14 04:20:41    5068534   98836     280958  4688740
# 11  2021-04-15 04:20:54    5111882   99133     283059  4729690
# 12  2021-04-09 04:21:13    4903965   97422     274401  4532142
# 13  2021-04-10 04:20:59    4903965   97422     274401  4531995
# 14  2021-04-16 04:20:46    5149776   99427     284943  4765406
# 15  2021-04-17 04:20:40    5186109   99758     286830  4799521
# 16  2021-04-18 04:20:41    5221888   99947     288182  4833759
# 17  2021-04-19 04:20:57    5249622  100075     288664  4860883

# %%
df_time_test = pd.read_sql("SELECT * FROM dim_time LIMIT 3", conn)
df_time_test
# Out:
#            last_update date_string  hour  day  week  month  year  weekday
# 0  2021-01-02 05:22:33  2021-01-02     5    2    53      1  2021        5
# 1  2020-12-21 13:27:30  2020-12-21    13   21    52     12  2020        0
# 2  2020-08-04 02:27:56  2020-08-04     2    4    32      8  2020        1

# %%
df_csv_test = pd.read_sql("SELECT * FROM csv_record LIMIT 3", conn)
df_csv_test
# Out:
#          file_name data_type          last_update
# 0  Afghanistan.csv       vac  2021-04-17 15:37:11
# 1      Albania.csv       vac  2021-04-17 15:37:11
# 2      Algeria.csv       vac  2021-04-17 15:37:11

# %% [markdown]
# #### Vaccination data

# %%
etl.process_vaccine_data(process_all=True)
# Out:
# ----- Start processing vaccination data -----
# Loading and processing vaccination data...
# Afghanistan.csv
# Albania.csv
# Algeria.csv
# Andorra.csv
# Angola.csv
# Anguilla.csv
# Antigua and Barbuda.csv
# Argentina.csv
# Armenia.csv
# Aruba.csv
# Australia.csv
# Austria.csv
# Azerbaijan.csv
# Bahamas.csv
# Bahrain.csv
# Bangladesh.csv
# Barbados.csv
# Belarus.csv
# Belgium.csv
# Belize.csv
# Benin.csv
# Bermuda.csv
# Bhutan.csv
# Bolivia.csv
# Bonaire Sint Eustatius and Saba.csv
# Bosnia and Herzegovina.csv
# Botswana.csv
# Brazil.csv
# British Virgin Islands.csv
# Brunei.csv
# Bulgaria.csv
# Burkina Faso.csv
# Cambodia.csv
# Cameroon.csv
# Canada.csv
# Cape Verde.csv
# Cayman Islands.csv
# Central African Republic.csv
# Chad.csv
# Chile.csv
# China.csv
# Colombia.csv
# Comoros.csv
# Congo.csv
# Cook Islands.csv
# Costa Rica.csv
# Cote d'Ivoire.csv
# Croatia.csv
# Cuba.csv
# Curacao.csv
# Cyprus.csv
# Czechia.csv
# Democratic Republic of Congo.csv
# Denmark.csv
# Djibouti.csv
# Dominica.csv
# Dominican Republic.csv
# Ecuador.csv
# Egypt.csv
# El Salvador.csv
# England.csv
# Equatorial Guinea.csv
# Estonia.csv
# Eswatini.csv
# Ethiopia.csv
# Faeroe Islands.csv
# Falkland Islands.csv
# Fiji.csv
# Finland.csv
# France.csv
# French Polynesia.csv
# Gabon.csv
# Gambia.csv
# Georgia.csv
# Germany.csv
# Ghana.csv
# Gibraltar.csv
# Greece.csv
# Greenland.csv
# Grenada.csv
# Guatemala.csv
# Guernsey.csv
# Guinea-Bissau.csv
# Guinea.csv
# Guyana.csv
# Honduras.csv
# Hong Kong.csv
# Hungary.csv
# Iceland.csv
# India.csv
# Indonesia.csv
# Iran.csv
# Iraq.csv
# Ireland.csv
# Isle of Man.csv
# Israel.csv
# Italy.csv
# Jamaica.csv
# Japan.csv
# Jersey.csv
# Jordan.csv
# Kazakhstan.csv
# Kenya.csv
# Kosovo.csv
# Kuwait.csv
# Kyrgyzstan.csv
# Laos.csv
# Latvia.csv
# Lebanon.csv
# Lesotho.csv
# Liberia.csv
# Libya.csv
# Liechtenstein.csv
# Lithuania.csv
# Luxembourg.csv
# Macao.csv
# Madagascar.csv
# Malawi.csv
# Malaysia.csv
# Maldives.csv
# Mali.csv
# Malta.csv
# Mauritania.csv
# Mauritius.csv
# Mexico.csv
# Moldova.csv
# Monaco.csv
# Mongolia.csv
# Montenegro.csv
# Montserrat.csv
# Morocco.csv
# Mozambique.csv
# Myanmar.csv
# Namibia.csv
# Nauru.csv
# Nepal.csv
# Netherlands.csv
# New Caledonia.csv
# New Zealand.csv
# Nicaragua.csv
# Niger.csv
# Nigeria.csv
# North Macedonia.csv
# Northern Cyprus.csv
# Northern Ireland.csv
# Norway.csv
# Oman.csv
# Pakistan.csv
# Palau.csv
# Palestine.csv
# Panama.csv
# Papua New Guinea.csv
# Paraguay.csv
# Peru.csv
# Philippines.csv
# Pitcairn.csv
# Poland.csv
# Portugal.csv
# Qatar.csv
# Romania.csv
# Russia.csv
# Rwanda.csv
# Saint Helena.csv
# Saint Kitts and Nevis.csv
# Saint Lucia.csv
# Saint Vincent and the Grenadines.csv
# Samoa.csv
# San Marino.csv
# Sao Tome and Principe.csv
# Saudi Arabia.csv
# Scotland.csv
# Senegal.csv
# Serbia.csv
# Seychelles.csv
# Sierra Leone.csv
# Singapore.csv
# Sint Maarten (Dutch part).csv
# Slovakia.csv
# Slovenia.csv
# Solomon Islands.csv
# Somalia.csv
# South Africa.csv
# South Korea.csv
# South Sudan.csv
# Spain.csv
# Sri Lanka.csv
# Sudan.csv
# Suriname.csv
# Sweden.csv
# Switzerland.csv
# Syria.csv
# Taiwan.csv
# Tajikistan.csv
# Thailand.csv
# Timor.csv
# Togo.csv
# Tonga.csv
# Trinidad and Tobago.csv
# Tunisia.csv
# Turkey.csv
# Turkmenistan.csv
# Turks and Caicos Islands.csv
# Tuvalu.csv
# Uganda.csv
# Ukraine.csv
# United Arab Emirates.csv
# United Kingdom.csv
# United States.csv
# Uruguay.csv
# Uzbekistan.csv
# Vanuatu.csv
# Venezuela.csv
# Vietnam.csv
# Wales.csv
# Wallis and Futuna.csv
# Yemen.csv
# Zambia.csv
# Zimbabwe.csv
# Bulk inserting processed vaccination data into vaccination table...
#       location date_string    date_org             vaccine total_vaccinations  \
# 0  Afghanistan  2021-02-22  2021-02-22  Oxford/AstraZeneca                  0
# 1  Afghanistan  2021-02-28  2021-02-28  Oxford/AstraZeneca               8200
# 2  Afghanistan  2021-03-16  2021-03-16  Oxford/AstraZeneca              54000
# 3  Afghanistan  2021-04-07  2021-04-07  Oxford/AstraZeneca             120000
# 4  Afghanistan  2021-04-22  2021-04-22  Oxford/AstraZeneca             240000
#
#   people_vaccinated people_fully_vaccinated
# 0                 0                    None
# 1              8200                    None
# 2             54000                    None
# 3            120000                    None
# 4            240000                    None
# Done bulk insert vaccination data into vaccination table
# Bulk inserting csv records into csv_record table...
# (%s, %s, %s)
# Done bulk insert csv records into csv_record table
# ----- Successfully process vaccination data and insert into vaccination table -----
# ---------------------------------------

# %%
df_vac_test = pd.read_sql("SELECT * FROM vac LIMIT 10", conn)

# %%
df_vac_test
# Out:
#       location date_string    date_org             vaccine  \
# 0  Afghanistan  2021-02-22  2021-02-22  Oxford/AstraZeneca
# 1  Afghanistan  2021-02-28  2021-02-28  Oxford/AstraZeneca
# 2  Afghanistan  2021-03-16  2021-03-16  Oxford/AstraZeneca
# 3  Afghanistan  2021-04-07  2021-04-07  Oxford/AstraZeneca
# 4      Albania  2021-01-10  2021-01-10     Pfizer/BioNTech
# 5      Albania  2021-01-12  2021-01-12     Pfizer/BioNTech
# 6      Albania  2021-01-13  2021-01-13     Pfizer/BioNTech
# 7      Albania  2021-01-14  2021-01-14     Pfizer/BioNTech
# 8      Albania  2021-01-15  2021-01-15     Pfizer/BioNTech
# 9      Albania  2021-01-16  2021-01-16     Pfizer/BioNTech
#
#    total_vaccinations  people_vaccinated people_fully_vaccinated
# 0                   0                  0                    None
# 1                8200               8200                    None
# 2               54000              54000                    None
# 3              120000             120000                    None
# 4                   0                  0                    None
# 5                 128                128                    None
# 6                 188                188                    None
# 7                 266                266                    None
# 8                 308                308                    None
# 9                 369                369                    None

# %% [markdown]
# #### country location data

# %%
etl.process_country_location()
# Out:
# ----- Start processing country/location data -----
# Loading country data...
#    UID iso2 iso3  code3  FIPS Admin2 Province_State Country_Region       Lat  \
# 0    4   AF  AFG    4.0   NaN    NaN            NaN    Afghanistan  33.93911
# 1    8   AL  ALB    8.0   NaN    NaN            NaN        Albania  41.15330
# 2   12   DZ  DZA   12.0   NaN    NaN            NaN        Algeria  28.03390
# 3   20   AD  AND   20.0   NaN    NaN            NaN        Andorra  42.50630
# 4   24   AO  AGO   24.0   NaN    NaN            NaN         Angola -11.20270
#
#        Long_ Combined_Key  Population
# 0  67.709953  Afghanistan  38928341.0
# 1  20.168300      Albania   2877800.0
# 2   1.659600      Algeria  43851043.0
# 3   1.521800      Andorra     77265.0
# 4  17.873900       Angola  32866268.0
# Loading location data...
# Transforming location data...
#   Country_Region     location continent
# 0    Afghanistan  Afghanistan      Asia
# 1        Albania      Albania    Europe
# 2        Algeria      Algeria    Africa
# 3        Andorra      Andorra    Europe
# 4         Angola       Angola    Africa
# Inserting processed country_loc data into country_loc table...
# Done inserting country_loc data into country_loc table
# ----- Successfully process country_loc data and insert into country_loc table -----
# ---------------------------------------

# %%
df_cc_test = pd.read_sql("SELECT * FROM country_loc LIMIT 10", conn)

# %%
df_cc_test
# Out:
#         country_region             location  uid iso2 iso3  code3 fips admin2  \
# 0          Afghanistan          Afghanistan    4   AF  AFG      4
# 1              Albania              Albania    8   AL  ALB      8
# 2              Algeria              Algeria   12   DZ  DZA     12
# 3              Andorra              Andorra   20   AD  AND     20
# 4               Angola               Angola   24   AO  AGO     24
# 5  Antigua and Barbuda  Antigua and Barbuda   28   AG  ATG     28
# 6            Argentina            Argentina   32   AR  ARG     32
# 7              Armenia              Armenia   51   AM  ARM     51
# 8              Austria              Austria   40   AT  AUT     40
# 9           Azerbaijan           Azerbaijan   31   AZ  AZE     31
#
#   province_state         combined_key       lat     long_  population  \
# 0                         Afghanistan  33.93911  67.70995    38928341
# 1                             Albania  41.15330  20.16830     2877800
# 2                             Algeria  28.03390   1.65960    43851043
# 3                             Andorra  42.50630   1.52180       77265
# 4                              Angola -11.20270  17.87390    32866268
# 5                 Antigua and Barbuda  17.06080 -61.79640       97928
# 6                           Argentina -38.41610 -63.61670    45195777
# 7                             Armenia  40.06910  45.03820     2963234
# 8                             Austria  47.51620  14.55010     9006400
# 9                          Azerbaijan  40.14310  47.57690    10139175
#
#        continent
# 0           Asia
# 1         Europe
# 2         Africa
# 3         Europe
# 4         Africa
# 5  North America
# 6  South America
# 7           Asia
# 8         Europe
# 9           Asia

# %% [markdown]
# ### Data warehouse check part

# %%
etl.check_country_loc_table(conn, cur)

# %%
etl.check_case_time_table(conn,cur)
# Out:
# All dates from csv_records are found in case table dates
# All dates from case table are found in csv_records
# All dates from csv_records are found in dim_time table dates
# All dates from dim_time table are found in csv_records
# The following regions from case lookup file are not found in case table regions: Western Sahara,Palau
# ['Niger', 'Ogun', 'Bayelsa', 'Federal Capital Territory', 'Kaduna', 'Ebonyi', 'Ondo', 'Jigawa', 'Oyo', 'Rivers', 'Taraba', 'Benue', 'Enugu', 'Plateau', 'Abia', 'Kogi', 'Federal Bureau of Prisons', 'Kano', 'Kebbi', 'Katsina', 'Ekiti', 'Anambra', 'Bauchi', 'Adamawa', 'Zamfara', 'Cross River', 'Veteran Hospitals', 'Akwa Ibom', 'Gombe', 'Delta', 'US Military', 'Borno', 'Imo', 'Kwara', 'Osun', 'Lagos', 'Yobe', 'Nasarawa', 'Edo', 'Sokoto']
# The following provinces from case lookup file are not found in case table provinces: Niger,Ogun,Bayelsa,Federal Capital Territory,Kaduna,Ebonyi,Ondo,Jigawa,Oyo,Rivers,Taraba,Benue,Enugu,Plateau,Abia,Kogi,Federal Bureau of Prisons,Kano,Kebbi,Katsina,Ekiti,Anambra,Bauchi,Adamawa,Zamfara,Cross River,Veteran Hospitals,Akwa Ibom,Gombe,Delta,US Military,Borno,Imo,Kwara,Osun,Lagos,Yobe,Nasarawa,Edo,Sokoto

# %%
etl.check_vac_table(conn,cur)
# Out:
# ['Albania', 'Algeria', 'Andorra', 'Angola', 'Anguilla', 'Argentina', 'Australia', 'Austria', 'Azerbaijan', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Bermuda', 'Bolivia', 'Brazil', 'Bulgaria', 'Cambodia', 'Canada', 'Cayman Islands', 'Chile', 'China', 'Colombia', 'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cyprus', 'Czechia', 'Denmark', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'England', 'Estonia', 'Faeroe Islands', 'Falkland Islands', 'Finland', 'France', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guatemala', 'Guernsey', 'Guinea', 'Guyana', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Japan', 'Jersey', 'Jordan', 'Kazakhstan', 'Kenya', 'Kuwait', 'Latvia', 'Lebanon', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao', 'Malaysia', 'Maldives', 'Malta', 'Mauritius', 'Mexico', 'Moldova', 'Monaco', 'Mongolia', 'Montenegro', 'Montserrat', 'Morocco', 'Myanmar', 'Nepal', 'Netherlands', 'New Zealand', 'Northern Cyprus', 'Northern Ireland', 'Norway', 'Oman', 'Pakistan', 'Palau', 'Panama', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Qatar', 'Romania', 'Russia', 'Rwanda', 'Saint Helena', 'Saint Lucia', 'San Marino', 'Saudi Arabia', 'Scotland', 'Senegal', 'Serbia', 'Seychelles', 'Singapore', 'Slovakia', 'Slovenia', 'South Africa', 'South Korea', 'Spain', 'Sri Lanka', 'Sweden', 'Switzerland', 'Thailand', 'Trinidad and Tobago', 'Turkey', 'Turks and Caicos Islands', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United States', 'Uruguay', 'Venezuela', 'Wales', 'Zimbabwe']
# ['Indonesia', 'Bangladesh', 'Venezuela', 'Luxembourg', 'Sweden', 'Montenegro', 'Jordan', 'Dominican Republic', 'Saint Helena', 'Ireland', 'Cambodia', 'Singapore', 'Sri Lanka', 'San Marino', 'Portugal', 'Finland', 'Malta', 'Colombia', 'Wales', 'Albania', 'Ukraine', 'Saudi Arabia', 'Grenada', 'Cayman Islands', "Cote d'Ivoire", 'Latvia', 'Northern Ireland', 'Algeria', 'France', 'Slovakia', '