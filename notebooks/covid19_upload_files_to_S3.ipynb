# %%
import git
repo = git.Repo('.', search_parent_directories=True)
repo_loc = repo.working_tree_dir

import os
import sys
from pathlib import Path
import configparser

sys.path.append(repo_loc)

# %%
from src import download_file

# %%
# If want to download files from specific date(s)
file_date = ['2021-07-08', '2021-07-20'] # Specify the start and end dates of files to download
download_file.dl_case_files(file_date=file_date)
# Out:
# 07-08-2021.csv
# Upload Successful
# 07-09-2021.csv
# Upload Successful
# 07-10-2021.csv
# Upload Successful
# 07-11-2021.csv
# Upload Successful
# 07-12-2021.csv
# Upload Successful
# 07-13-2021.csv
# Upload Successful
# 07-14-2021.csv
# Upload Successful
# 07-15-2021.csv
# Upload Successful
# 07-16-2021.csv
# Upload Successful
# 07-17-2021.csv
# Upload Successful
# 07-18-2021.csv
# Upload Successful

# %%
download_file.dl_case_files()
# Out:
# 04-16-2021.csv
# Upload Successful
# 04-17-2021.csv
# Upload Successful
# 04-18-2021.csv
# Upload Successful

# %%
download_file.dl_vac_files()
# Out:
# Afghanistan.csv
# Upload Successful
# Albania.csv
# Upload Successful
# Algeria.csv
# Upload Successful
# Andorra.csv
# Upload Successful
# Angola.csv
# Upload Successful
# Anguilla.csv
# Upload Successful
# Antigua and Barbuda.csv
# Upload Successful
# Argentina.csv
# Upload Successful
# Armenia.csv
# Upload Successful
# Australia.csv
# Upload Successful
# Austria.csv
# Upload Successful
# Azerbaijan.csv
# Upload Successful
# Bahamas.csv
# Upload Successful
# Bahrain.csv
# Upload Successful
# Bangladesh.csv
# Upload Successful
# Barbados.csv
# Upload Successful
# Belarus.csv
# Upload Successful
# Belgium.csv
# Upload Successful
# Belize.csv
# Upload Successful
# Bermuda.csv
# Upload Successful
# Bhutan.csv
# Upload Successful
# Bolivia.csv
# Upload Successful
# Bosnia and Herzegovina.csv
# Upload Successful
# Botswana.csv
# Upload Successful
# Brazil.csv
# Upload Successful
# Brunei.csv
# Upload Successful
# Bulgaria.csv
# Upload Successful
# Cambodia.csv
# Upload Successful
# Cameroon.csv
# Upload Successful
# Canada.csv
# Upload Successful
# Cape Verde.csv
# Upload Successful
# Cayman Islands.csv
# Upload Successful
# Chile.csv
# Upload Successful
# China.csv
# Upload Successful
# Colombia.csv
# Upload Successful
# Costa Rica.csv
# Upload Successful
# Cote d'Ivoire.csv
# Upload Successful
# Croatia.csv
# Upload Successful
# Cyprus.csv
# Upload Successful
# Czechia.csv
# Upload Successful
# Denmark.csv
# Upload Successful
# Dominica.csv
# Upload Successful
# Dominican Republic.csv
# Upload Successful
# Ecuador.csv
# Upload Successful
# Egypt.csv
# Upload Successful
# El Salvador.csv
# Upload Successful
# England.csv
# Upload Successful
# Equatorial Guinea.csv
# Upload Successful
# Estonia.csv
# Upload Successful
# Eswatini.csv
# Upload Successful
# Faeroe Islands.csv
# Upload Successful
# Falkland Islands.csv
# Upload Successful
# Fiji.csv
# Upload Successful
# Finland.csv
# Upload Successful
# France.csv
# Upload Successful
# Gabon.csv
# Upload Successful
# Gambia.csv
# Upload Successful
# Georgia.csv
# Upload Successful
# Germany.csv
# Upload Successful
# Ghana.csv
# Upload Successful
# Gibraltar.csv
# Upload Successful
# Greece.csv
# Upload Successful
# Greenland.csv
# Upload Successful
# Grenada.csv
# Upload Successful
# Guatemala.csv
# Upload Successful
# Guernsey.csv
# Upload Successful
# Guinea.csv
# Upload Successful
# Guyana.csv
# Upload Successful
# Honduras.csv
# Upload Successful
# Hong Kong.csv
# Upload Successful
# Hungary.csv
# Upload Successful
# Iceland.csv
# Upload Successful
# India.csv
# Upload Successful
# Indonesia.csv
# Upload Successful
# Iran.csv
# Upload Successful
# Iraq.csv
# Upload Successful
# Ireland.csv
# Upload Successful
# Isle of Man.csv
# Upload Successful
# Israel.csv
# Upload Successful
# Italy.csv
# Upload Successful
# Jamaica.csv
# Upload Successful
# Japan.csv
# Upload Successful
# Jersey.csv
# Upload Successful
# Jordan.csv
# Upload Successful
# Kazakhstan.csv
# Upload Successful
# Kenya.csv
# Upload Successful
# Kosovo.csv
# Upload Successful
# Kuwait.csv
# Upload Successful
# Kyrgyzstan.csv
# Upload Successful
# Laos.csv
# Upload Successful
# Latvia.csv
# Upload Successful
# Lebanon.csv
# Upload Successful
# Liechtenstein.csv
# Upload Successful
# Lithuania.csv
# Upload Successful
# Luxembourg.csv
# Upload Successful
# Macao.csv
# Upload Successful
# Malawi.csv
# Upload Successful
# Malaysia.csv
# Upload Successful
# Maldives.csv
# Upload Successful
# Mali.csv
# Upload Successful
# Malta.csv
# Upload Successful
# Mauritania.csv
# Upload Successful
# Mauritius.csv
# Upload Successful
# Mexico.csv
# Upload Successful
# Moldova.csv
# Upload Successful
# Monaco.csv
# Upload Successful
# Mongolia.csv
# Upload Successful
# Montenegro.csv
# Upload Successful
# Montserrat.csv
# Upload Successful
# Morocco.csv
# Upload Successful
# Mozambique.csv
# Upload Successful
# Myanmar.csv
# Upload Successful
# Namibia.csv
# Upload Successful
# Nepal.csv
# Upload Successful
# Netherlands.csv
# Upload Successful
# New Zealand.csv
# Upload Successful
# Nigeria.csv
# Upload Successful
# North Macedonia.csv
# Upload Successful
# Northern Cyprus.csv
# Upload Successful
# Northern Ireland.csv
# Upload Successful
# Norway.csv
# Upload Successful
# Oman.csv
# Upload Successful
# Pakistan.csv
# Upload Successful
# Palau.csv
# Upload Successful
# Palestine.csv
# Upload Successful
# Panama.csv
# Upload Successful
# Papua New Guinea.csv
# Upload Successful
# Paraguay.csv
# Upload Successful
# Peru.csv
# Upload Successful
# Philippines.csv
# Upload Successful
# Poland.csv
# Upload Successful
# Portugal.csv
# Upload Successful
# Qatar.csv
# Upload Successful
# Romania.csv
# Upload Successful
# Russia.csv
# Upload Successful
# Rwanda.csv
# Upload Successful
# Saint Helena.csv
# Upload Successful
# Saint Kitts and Nevis.csv
# Upload Successful
# Saint Lucia.csv
# Upload Successful
# Saint Vincent and the Grenadines.csv
# Upload Successful
# San Marino.csv
# Upload Successful
# Sao Tome and Principe.csv
# Upload Successful
# Saudi Arabia.csv
# Upload Successful
# Scotland.csv
# Upload Successful
# Senegal.csv
# Upload Successful
# Serbia.csv
# Upload Successful
# Seychelles.csv
# Upload Successful
# Sierra Leone.csv
# Upload Successful
# Singapore.csv
# Upload Successful
# Slovakia.csv
# Upload Successful
# Slovenia.csv
# Upload Successful
# Solomon Islands.csv
# Upload Successful
# South Africa.csv
# Upload Successful
# South Korea.csv
# Upload Successful
# South Sudan.csv
# Upload Successful
# Spain.csv
# Upload Successful
# Sri Lanka.csv
# Upload Successful
# Sudan.csv
# Upload Successful
# Suriname.csv
# Upload Successful
# Sweden.csv
# Upload Successful
# Switzerland.csv
# Upload Successful
# Syria.csv
# Upload Successful
# Taiwan.csv
# Upload Successful
# Thailand.csv
# Upload Successful
# Togo.csv
# Upload Successful
# Trinidad and Tobago.csv
# Upload Successful
# Tunisia.csv
# Upload Successful
# Turkey.csv
# Upload Successful
# Turks and Caicos Islands.csv
# Upload Successful
# Uganda.csv
# Upload Successful
# Ukraine.csv
# Upload Successful
# United Arab Emirates.csv
# Upload Successful
# United Kingdom.csv
# Upload Successful
# United States.csv
# Upload Successful
# Uruguay.csv
# Upload Successful
# Uzbekistan.csv
# Upload Successful
# Venezuela.csv
# Upload Successful
# Vietnam.csv
# Upload Successful
# Wales.csv
# Upload Successful
# Zambia.csv
# Upload Successful
# Zimbabwe.csv
# Upload Successful

# %%
download_file.dl_lookup_files()
# Out:
# Upload Successful
# Upload Successful

# %%
print(list_files)
# Out:
# ['test.csv']

# %%
# for o in my_bucket.objects.filter(Prefix=folder):
#     print(o.key)
# Out:
# daily_case_data/
# daily_case_data/old_format/
# daily_case_data/test.csv
