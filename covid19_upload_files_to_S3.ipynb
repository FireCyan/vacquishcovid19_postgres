# %%
import configparser

# %%
import download_file

# %%
# If want to download files from specific date(s)
file_date = ['2020-11-01', '2021-06-05'] # Specify the start and end dates of files to download
download_file.dl_case_files(file_date=file_date)
# Out:
# 01-01-2021.csv
# Upload Successful
# 01-02-2021.csv
# Upload Successful
# 01-03-2021.csv
# Upload Successful
# 01-04-2021.csv
# Upload Successful
# 01-05-2021.csv
# Upload Successful
# 01-06-2021.csv
# Upload Successful
# 01-07-2021.csv
# Upload Successful
# 01-08-2021.csv
# Upload Successful
# 01-09-2021.csv
# Upload Successful
# 01-10-2021.csv
# Upload Successful
# 01-11-2021.csv
# Upload Successful
# 01-12-2021.csv
# Upload Successful
# 01-13-2021.csv
# Upload Successful
# 01-14-2021.csv
# Upload Successful
# 01-15-2021.csv
# Upload Successful
# 01-16-2021.csv
# Upload Successful
# 01-17-2021.csv
# Upload Successful
# 01-18-2021.csv
# Upload Successful
# 01-19-2021.csv
# Upload Successful
# 01-20-2021.csv
# Upload Successful
# 01-21-2021.csv
# Upload Successful
# 01-22-2021.csv
# Upload Successful
# 01-23-2021.csv
# Upload Successful
# 01-24-2021.csv
# Upload Successful
# 01-25-2021.csv
# Upload Successful
# 01-26-2021.csv
# Upload Successful
# 01-27-2021.csv
# Upload Successful
# ...

# %%
download_file.dl_case_files()
# Out:
# 04-16-2021.csv
# Upload Successful
# 04-17-2021.csv
# Upload Successful
# 04-18-2021.csv
# Upload Successful

# %%
download_file.dl_vac_files()
# Out:
# Afghanistan.csv
# Upload Successful
# Albania.csv
# Upload Successful
# Algeria.csv
# Upload Successful
# Andorra.csv
# Upload Successful
# Angola.csv
# Upload Successful
# Anguilla.csv
# Upload Successful
# Antigua and Barbuda.csv
# Upload Successful
# Argentina.csv
# Upload Successful
# Armenia.csv
# Upload Successful
# Australia.csv
# Upload Successful
# Austria.csv
# Upload Successful
# Azerbaijan.csv
# Upload Successful
# Bahamas.csv
# Upload Successful
# Bahrain.csv
# Upload Successful
# Bangladesh.csv
# Upload Successful
# Barbados.csv
# Upload Successful
# Belarus.csv
# Upload Successful
# Belgium.csv
# Upload Successful
# Belize.csv
# Upload Successful
# Bermuda.csv
# Upload Successful
# Bhutan.csv
# Upload Successful
# Bolivia.csv
# Upload Successful
# Bosnia and Herzegovina.csv
# Upload Successful
# Botswana.csv
# Upload Successful
# Brazil.csv
# Upload Successful
# Brunei.csv
# Upload Successful
# Bulgaria.csv
# Upload Successful
# Cambodia.csv
# Upload Successful
# ...

# %%
download_file.dl_lookup_files()
# Out:
# Upload Successful
# Upload Successful

# %%
print(list_files)
# Out:
# ['test.csv']

# %%
# for o in my_bucket.objects.filter(Prefix=folder):
#     print(o.key)
# Out:
# daily_case_data/
# daily_case_data/old_format/
# daily_case_data/test.csv
